# %% [markdown]
# # Proyecto Inteligencia Artificial
#
# ###Camilo Andres Barbosa Molina
#
# [GitHub](https://github.com/camilo28-Universidad/Proyecto-Inteligencia-Artificial/) Invitacón Enviada
#
# Dataset escogido: [Dataset](https://www.kaggle.com/neuromusic/avocado-prices)

# %% [markdown]
# #Primera Entrega

# %% [markdown]
# ##Contexto
# Es un hecho bien conocido que los Millenials AMAN las tostadas de aguacate. También es un hecho bien conocido que todos los Millenials viven en los sótanos de sus padres.
#
# **¡Claramente, no están comprando una casa porque están comprando demasiadas tostadas de aguacate!**
#
# Pero tal vez haya esperanza ... si un Millenial pudiera encontrar una ciudad con aguacates baratos, podría vivir el Sueño Americano del Milenio.
#
# Tomado de : [Website](https://www.kaggle.com/neuromusic/avocado-prices)

# %% [markdown]
# ##Contenido
# La siguiente tabla representa los datos de escaneo de minoristas semanales de 2018 para el volumen minorista nacional (unidades) y el precio. Los datos de escaneo minorista provienen directamente de las cajas registradoras de los minoristas en función de las ventas minoristas reales de aguacates Hass. A partir de 2013, la siguiente tabla refleja un conjunto ampliado de datos minoristas de múltiples puntos de venta. Los informes de múltiples puntos de venta incluyen una agregación de los siguientes canales: abarrotes, misa, clubes, drogas, dólares y militares. El precio promedio (de aguacates) en la tabla refleja un costo por unidad (por aguacate), incluso cuando se venden varias unidades (aguacates) en bolsas. Los códigos de búsqueda de productos (PLU) de la tabla son solo para aguacates Hass. Otras variedades de aguacates (por ejemplo, pieles verdes) no se incluyen en esta tabla.
#
#
# Tomado de : [Website](https://www.kaggle.com/neuromusic/avocado-prices)

# %% [markdown]
# ## Importar

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importar Dataset
#
# ¡Si no abre el NoteBook con el archivo .csv recuerda visitar el GitHub para obtenerlo, este se debe guardar en la carpeta sample_date!

# %%
#Importar Dataser con pd.read_csv
aguacates_data = pd.read_csv('sample_data/avocado.csv',index_col=1,parse_dates=True)
aguacates_data.drop(columns='Unnamed: 0',axis=1,inplace=True)
aguacates_data.index = pd.to_datetime(aguacates_data.index)

# %%
#Visualizar la data
aguacates_data
# Out:
#             AveragePrice  TotalVolume  ...  year            region
# Date                                   ...
# 2015-12-27          1.33     64236.62  ...  2015            Albany
# 2015-12-20          1.35     54876.98  ...  2015            Albany
# 2015-12-13          0.93    118220.22  ...  2015            Albany
# 2015-12-06          1.08     78992.15  ...  2015            Albany
# 2015-11-29          1.28     51039.60  ...  2015            Albany
# ...                  ...          ...  ...   ...               ...
# 2018-02-04          1.63     17074.83  ...  2018  WestTexNewMexico
# 2018-01-28          1.71     13888.04  ...  2018  WestTexNewMexico
# 2018-01-21          1.87     13766.76  ...  2018  WestTexNewMexico
# 2018-01-14          1.93     16205.22  ...  2018  WestTexNewMexico
# 2018-01-07          1.62     17489.58  ...  2018  WestTexNewMexico
#
# [18249 rows x 12 columns]

# %%
#Visualizar primeras  cinco filas de la data
aguacates_data.head()
# Out:
#          Date  AveragePrice  TotalVolume  ...          type  year  region
# 0  2015-12-27          1.33     64236.62  ...  conventional  2015  Albany
# 1  2015-12-20          1.35     54876.98  ...  conventional  2015  Albany
# 2  2015-12-13          0.93    118220.22  ...  conventional  2015  Albany
# 3  2015-12-06          1.08     78992.15  ...  conventional  2015  Albany
# 4  2015-11-29          1.28     51039.60  ...  conventional  2015  Albany
#
# [5 rows x 13 columns]

# %% [markdown]
# ##Información de columnas
# * Date: la fecha de la observación
# * AveragePrice: el precio medio de un solo aguacate
# * type: convencional u orgánico
# * year: el año
# * region: la ciudad o región de la observación
# * TotalVolume: número total de aguacates vendidos
# * 4046: Número total de aguacates con PLU 4046 vendidos
# * 4225: Número total de aguacates con PLU 4225 vendidos
# * 4770: Número total de aguacates con PLU 4770 vendidos

# %% [markdown]
# ## Análisis de datos

# %%
#Averguar la cantidad de datos de Dataframe
aguacates_data.shape
# Out:
# (18249, 13)

# %%
#Recordar comandos como loc y iloc para trabar con columnas y filas especificas
#de una DataFrame

aguacates_data.loc[:,['AveragePrice']]
# Out:
#     AveragePrice
# 0           1.33
# 1           1.35
# 2           0.93
# 3           1.08
# 4           1.28
# ..           ...
# 7           1.63
# 8           1.71
# 9           1.87
# 10          1.93
# 11          1.62
#
# [18249 rows x 1 columns]

# %%
#Otros ejemplos
aguacates_data.loc[aguacates_data.type.isin(['conventional'])]
# Out:
#           Date  AveragePrice  TotalVolume  ...          type  year            region
# 0   2015-12-27          1.33     64236.62  ...  conventional  2015            Albany
# 1   2015-12-20          1.35     54876.98  ...  conventional  2015            Albany
# 2   2015-12-13          0.93    118220.22  ...  conventional  2015            Albany
# 3   2015-12-06          1.08     78992.15  ...  conventional  2015            Albany
# 4   2015-11-29          1.28     51039.60  ...  conventional  2015            Albany
# ..         ...           ...          ...  ...           ...   ...               ...
# 7   2018-02-04          0.76   1272039.80  ...  conventional  2018  WestTexNewMexico
# 8   2018-01-28          0.85    957086.16  ...  conventional  2018  WestTexNewMexico
# 9   2018-01-21          0.84   1020913.20  ...  conventional  2018  WestTexNewMexico
# 10  2018-01-14          0.90    950954.60  ...  conventional  2018  WestTexNewMexico
# ...

# %%
#Revisar si existen valores nulos
#De manera Global
#aguacates_data.isnull()

#Realizar valores que existen dentro de una columna especifica
# agucates_data.Date.isnull().unique()
# agucates_data.AveragePrice.isnull().unique()
# agucates_data.TotalVolume.isnull().unique()
# agucates_data.PLU4046.isnull().unique()
# agucates_data.PLU4225.isnull().unique()
# agucates_data.PLU4770.isnull().unique()
# agucates_data.TotalBags.isnull().unique()
# agucates_data.SmallBags.isnull().unique()
# agucates_data.LargeBags.isnull().unique()
# agucates_data.XLargeBags.isnull().unique()
# agucates_data.type.isnull().unique()
# agucates_data.year.isnull().unique()
# agucates_data.region.isnull().unique()


#O de forma mas profunda

aguacates_data.loc[aguacates_data.region.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, TotalVolume, PLU4046, PLU4225, PLU4770, TotalBags, SmallBags, LargeBags, XLargeBags, type, year, region]
# Index: []

# %%
#Es importante reconocer vales unicos en columnas como type, year y region
#aguacates_data.type.unique()
#aguacates_data.year.unique()
aguacates_data.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
#Funciones como .describe permiten ver las operaciones como mean,count,std,min,max
#Para colummans como AveragePrice, TotalVolume y cada PLU
#aguacates_data.PLU4046.describe()
#aguacates_data.PLU4225.describe()
#aguacates_data.PLU4770.describe()
#aguacates_data.TotalVolume.describe()
aguacates_data.AveragePrice.describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %%
#la funcion groupby para realizar operaciones de acuerdo a una dos columnas
#aguacates_data.groupby(['Date']).AveragePrice.agg([len, min, max])
aguacates_data.groupby(['region']).AveragePrice.agg([ min, max])
# Out:
#                       min   max
# region
# Albany               0.85  2.13
# Atlanta              0.62  2.75
# BaltimoreWashington  0.95  2.28
# Boise                0.58  2.79
# Boston               0.85  2.19
# BuffaloRochester     1.03  2.57
# California           0.67  2.58
# Charlotte            0.80  2.83
# Chicago              0.70  2.30
# CincinnatiDayton     0.44  2.20
# Columbus             0.52  2.22
# DallasFtWorth        0.65  1.90
# Denver               0.60  2.16
# Detroit              0.48  2.08
# GrandRapids          0.77  2.73
# GreatLakes           0.73  1.98
# HarrisburgScranton   0.91  2.27
# HartfordSpringfield  0.86  2.68
# Houston              0.51  1.92
# Indianapolis         0.77  2.10
# Jacksonville         0.54  2.99
# LasVegas             0.54  3.03
# LosAngeles           0.53  2.44
# Louisville           0.56  2.29
# MiamiFtLauderdale    0.59  3.05
# Midsouth             0.91  2.17
# Nashville            0.51  2.24
# NewOrleansMobile     0.58  2.32
# ...

# %%
#Revisar el tipo de datos de todas las columnas y si es necesario cambiarla de tipo
aguacates_data.dtypes
#Como convertir la columna date a  tipo fecha
aguacates_data.Date = pd.to_datetime(aguacates_data['Date'])
aguacates_data.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# TotalVolume            float64
# PLU4046                float64
# PLU4225                float64
# PLU4770                float64
# TotalBags              float64
# SmallBags              float64
# LargeBags              float64
# XLargeBags             float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
#Revisar fecha mas antigua y fecha mas reciente
print(aguacates_data.Date.min())
print(aguacates_data.Date.max())
# Out:
# 2015-01-04
# 2018-03-25

# %%
#Realizar grafico de lineas de promedio de precios por año por meses de cada año
mean_month=aguacates_data['AveragePrice'].resample('M').mean()
plt.figure(figsize=(10,6))
plt.xlabel('meses')
plt.ylabel('promedio precios')
plt.title('Promedio de precios por mes en cada Año')
plt.plot(mean_month['2015'].values,label= '2015')
plt.plot(mean_month['2016'].values,label= '2016')
plt.plot(mean_month['2017'].values,label= '2017')
plt.plot(mean_month['2018'].values,label= '2018')
plt.legend()

# %%
invierno2014=aguacates_data.loc['2015-01-4':'2015-03-20']['AveragePrice']
primavera2015 = aguacates_data.loc['2015-03-21':'2015-06-20']['AveragePrice']
verano2015 = aguacates_data.loc['2015-05-21':'2015-09-20']['AveragePrice']
otoño2015 = aguacates_data.loc['2015-05-21':'2015-12-20']['AveragePrice']
invierno2015 = aguacates_data.loc['2015-12-21':'2016-03-20']['AveragePrice']

# %%
#Se realiza los graficos ya sea mediante subplots o mediante un grafico que encierre todas las estaciones para ver de mejor manera los cambios 
#a nivel de promedio de precio en cada un
fig.set_size_inches(20,20)  
plt.xlabel('Dias')
plt.ylabel('promedio precios')
plt.title('Promedio de precios por dias en la estación de invierno del año 2014')
plt.plot(invierno2014.values, label='Invierno 2014')

# %%
#Se realiza los graficos ya sea mediante subplots o mediante un grafico que encierre todas las estaciones para ver de mejor manera los cambios 
#a nivel de promedio de precio en cada una


# fig , ax = plt.subplots(3,2)
fig.set_size_inches(20,20)  
# ax[0,0].set_title('Invierno 2014')
# ax[0,0].plot(invierno2014.values)
# ax[0,1].set_title('Primavera 2015')
# ax[0,1].plot(primavera2015.values)
# ax[1,0].set_title('Verano 2015')
# ax[0,1].plot(verano2015.values)
# ax[1,1].set_title('Otoño 2015')
# ax[1,1].plot(otoño2015.values)
# ax[2,0].set_title('Invierno 2015')
# ax[2,0].plot(invierno2015.values)
# plt.plot(invierno2014.values)

plt.xlabel('Dias')
plt.ylabel('promedio precios')
plt.title('Promedio de precios por dias en cada estación del año 2015')
plt.plot(primavera2015.values, label='Primavera 2015')
plt.plot(verano2015.values, label='Verano 2015')
plt.plot(otoño2015.values, label='Otoño 2015')
plt.plot(invierno2015.values, label='Invierno 2015')
plt.legend()

# %%
primavera2016 = aguacates_data.loc['2016-03-21':'2016-06-20']['AveragePrice']
verano2016 = aguacates_data.loc['2016-06-21':'2016-09-20']['AveragePrice']
otoño2016 = aguacates_data.loc['2016-09-21':'2016-12-20']['AveragePrice']
invierno2016 = aguacates_data.loc['2016-12-21':'2017-03-20']['AveragePrice']

# %%
# fig , ax = plt.subplots(2,2)
fig.set_size_inches(15,8)
# ax[0,0].set_title('Primavera 2016')
# ax[0,0].plot(primavera2016.values)
# ax[0,1].set_title('Verano 2016')
# ax[0,1].plot(verano2016.values)
# ax[1,0].set_title('Otoño 2016')
# ax[1,0].plot(otoño2016.values)
# ax[1,1].set_title('Invierno 2016')
# ax[1,1].plot(invierno2016.values)

plt.xlabel('Dias')
plt.ylabel('promedio precios')
plt.title('Promedio de precios por dias en cada estación del año 2016')
plt.plot(primavera2016.values, label='Primavera 2016')
plt.plot(verano2016.values, label='Verano 2016')
plt.plot(otoño2016.values, label='Otoño 2016')
plt.plot(invierno2016.values, label='Invierno 2016')
plt.legend()

# %%
primavera2017 = aguacates_data.loc['2017-03-21':'2017-06-20']['AveragePrice']
verano2017 = aguacates_data.loc['2017-06-21':'2017-09-20']['AveragePrice']
otoño2017 = aguacates_data.loc['2017-09-21':'2017-12-20']['AveragePrice']
invierno2017 = aguacates_data.loc['2017-12-21':'2018-03-25']['AveragePrice']
# Out:
# Date
# 2017-06-18    1.58
# 2017-06-11    1.65
# 2017-06-04    1.70
# 2017-05-28    1.80
# 2017-05-21    1.38
#               ...
# 2017-04-23    1.63
# 2017-04-16    1.23
# 2017-04-09    1.19
# 2017-04-02    1.04
# 2017-03-26    1.11
# Name: AveragePrice, Length: 1403, dtype: float64

# %%
# fig , ax = plt.subplots(2,2)
fig.set_size_inches(15,8)
# ax[0,0].set_title('Primavera 2017')
# ax[0,0].plot(primavera2017.values)
# ax[0,1].set_title('Verano 2017')
# ax[0,1].plot(verano2017.values)
# ax[1,0].set_title('Otoño 2017')
# ax[1,0].plot(otoño2017.values)
# ax[1,1].set_title('Invierno 2017')
# ax[1,1].plot(invierno2017.values)


plt.xlabel('Dias')
plt.ylabel('promedio precios')
plt.title('Promedio de precios por dias en cada estación del año 2017')
plt.plot(primavera2017.values, label='Primavera 2017')
plt.plot(verano2017.values, label='Verano 2017')
plt.plot(otoño2017.values, label='Otoño 2017')
plt.plot(invierno2017.values, label='Invierno 2017')
plt.legend()

# %%
import seaborn as sbn
sbn.set(rc={'figure.figsize':(10, 10)})

# %%
#Otras formas de ver los datos con la libreria seaborn
aguacates_data['AveragePrice'].plot(linewidth=0.1, xlabel='Dates', ylabel='Promedio precios')

# %%
#En vex de lineas de hace uso de puntos para ver de mejor manera
aguacates_data['AveragePrice'].plot(marker='.',linewidth=0.1,alpha=0.1, linestyle='None', xlabel='Dates', ylabel='Promedio precios')
